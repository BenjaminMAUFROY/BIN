# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from skimage import data,filters, io, img_as_float
image = io.imread("bin/BN_Tri_entrainement/G0046882.JPG")
# image = img_as_float(image)
print(np.shape(image))
print(io.imshow(image[:,:,0]))
# image_laplacian = filters.gaussian(image)
# image_laplacian = filters.laplace(image_laplacian)
# io.imshow(image_laplacian)

# val = filters.threshold_otsu(image)
# mask = image < val
# io.imshow(mask)
# io.imshow(filters.sobel(image))

# edges = filters.sobel(image)
# plt.imshow(edges)
# Out:
# (3000, 4000, 3)
# AxesImage(shape=(3000, 4000))
# C:\Users\benji\AppData\Local\Temp\ipykernel_12788\3248273386.py:9: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   print(io.imshow(image[:,:,0]))

# %%
from skimage import io, exposure
import matplotlib.pyplot as plt

# Load the input image 
image = io.imread("bin/BN_Tri_entrainement/G0046882.JPG")

# Increase contrast by stretching the intensity range
high_contrast_image = exposure.rescale_intensity(image[:,:,0], in_range=(0, 150), out_range=(0, 1))

# Display the original and high-contrast images
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
ax1, ax2 = axes.ravel()

ax1.imshow(image, cmap='gray')
ax1.set_title('Original Image')
ax1.set_axis_off()

ax2.imshow(high_contrast_image, cmap='gray')
ax2.set_title('High Contrast Image')
ax2.set_axis_off()

plt.show()

image_laplacian = filters.laplace(high_contrast_image)
io.imshow(image_laplacian)
# Out:
# C:\Users\benji\AppData\Local\Temp\ipykernel_12788\2522171512.py:25: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(image_laplacian)
